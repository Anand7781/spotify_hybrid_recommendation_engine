# %%
# !pip install kagglehub --upgrade

# %%
import kagglehub

import os
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msn

# %%
kagglehub.dataset_download('undefinenull/million-song-dataset-spotify-lastfm')
# Out:
# Using Colab cache for faster access to the 'million-song-dataset-spotify-lastfm' dataset.
# '/kaggle/input/million-song-dataset-spotify-lastfm'

# %%
data_path = Path('/kaggle/input/million-song-dataset-spotify-lastfm')

songs_data = pd.read_csv(data_path / 'Music Info.csv')
user_data = pd.read_csv(data_path / 'User Listening History.csv')

# %%
songs_data
# Out:
#                  track_id                name                 artist  \
# 0      TRIOREW128F424EAF0      Mr. Brightside            The Killers
# 1      TRRIVDJ128F429B0E8          Wonderwall                  Oasis
# 2      TROUVHL128F426C441     Come as You Are                Nirvana
# 3      TRUEIND128F93038C4         Take Me Out        Franz Ferdinand
# 4      TRLNZBD128F935E4D8               Creep              Radiohead
# ...                   ...                 ...                    ...
# 50678  TRQYCFV128F9322F50       Ryusei Rocket            アンティック-珈琲店-
# 50679  TRHQCSH128F42724B7  Colors Of The Wind                ACIDMAN
# 50680  TRZRODK128F92D68D7      The Revelation               coldrain
# 50681  TRGLMEM128F9322F63   Koi no Dependence            アンティック-珈琲店-
# 50682  TRIPFKO128F42383FE         Hide & Seek  9mm Parabellum Bullet
#
#                                      spotify_preview_url  \
# 0      https://p.scdn.co/mp3-preview/4d26180e6961fd46...
# ...

# %%
songs_data.isna().sum()
# Out:
# track_id                   0
# name                       0
# artist                     0
# spotify_preview_url        0
# spotify_id                 0
# tags                    1127
# genre                  28335
# year                       0
# duration_ms                0
# danceability               0
# energy                     0
# key                        0
# loudness                   0
# mode                       0
# speechiness                0
# acousticness               0
# instrumentalness           0
# liveness                   0
# valence                    0
# tempo                      0
# time_signature             0
# dtype: int64

# %%
songs_data.isna().mean().sort_values(ascending=False).mul(100).head(5)
# Out:
# genre       55.906320
# tags         2.223625
# artist       0.000000
# name         0.000000
# track_id     0.000000
# dtype: float64

# %%
songs_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
songs_data.drop_duplicates(subset=['spotify_id','year','duration_ms'],inplace=True)

# %%
songs_data.reset_index(drop=True,inplace=True)

# %%
col_to_remove = ['track_id','name','spotify_preview_url','spotify_id','genre']

df_colab_filtering = songs_data.drop(columns=col_to_remove)

df_colab_filtering
# Out:
#                       artist  \
# 0                The Killers
# 1                      Oasis
# 2                    Nirvana
# 3            Franz Ferdinand
# 4                  Radiohead
# ...                      ...
# 50669            アンティック-珈琲店-
# 50670                ACIDMAN
# 50671               coldrain
# 50672            アンティック-珈琲店-
# 50673  9mm Parabellum Bullet
#
#                                                     tags  year  duration_ms  \
# 0      rock, alternative, indie, alternative_rock, in...  2004       222200
# 1      rock, alternative, indie, pop, alternative_roc...  2006       258613
# 2       rock, alternative, alternative_rock, 90s, grunge  1991       218920
# 3      rock, alternative, indie, alternative_rock, in...  2004       237026
# 4      rock, alternative, indie, alternative_rock, in...  2008       238640
# ...                                                  ...   ...          ...
# ...

# %%
df_colab_filtering.isna().sum()
# Out:
# artist                 0
# tags                1126
# year                   0
# duration_ms            0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# time_signature         0
# dtype: int64

# %%
# replacing tags with no_tags

df_colab_filtering.fillna({'tags':'no_tags'},inplace=True)

# %%
df_colab_filtering.isna().sum()
# Out:
# artist              0
# tags                0
# year                0
# duration_ms         0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
# unique artists
songs_data.loc[:,'artist'].nunique()
# Out:
# 8317

# %%
songs_data.loc[:,'year'].nunique()
# Out:
# 75

# %%
songs_data.loc[:,'tags'].str.lower().str.split(",").explode().str.strip().value_counts()
# Out:
# tags
# rock            10681
# indie            7284
# electronic       6592
# alternative      6271
# pop              4650
#                 ...
# dark_ambient      602
# japanese          489
# polish            411
# j_pop             213
# russian           127
# Name: count, Length: 100, dtype: int64

# %%
songs_data.loc[:,'tags'].str.lower().str.split(",").explode().str.strip().value_counts().loc[lambda ser: ser>= 1000 ]
# Out:
# tags
# rock            10681
# indie            7284
# electronic       6592
# alternative      6271
# pop              4650
#                 ...
# ska              1088
# gothic_metal     1072
# grindcore        1040
# french           1018
# nu_metal         1006
# Name: count, Length: 85, dtype: int64

# %%
# !pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from category_encoders.count import CountEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df_colab_filtering
# Out:
#                       artist  \
# 0                The Killers
# 1                      Oasis
# 2                    Nirvana
# 3            Franz Ferdinand
# 4                  Radiohead
# ...                      ...
# 50669            アンティック-珈琲店-
# 50670                ACIDMAN
# 50671               coldrain
# 50672            アンティック-珈琲店-
# 50673  9mm Parabellum Bullet
#
#                                                     tags  year  duration_ms  \
# 0      rock, alternative, indie, alternative_rock, in...  2004       222200
# 1      rock, alternative, indie, pop, alternative_roc...  2006       258613
# 2       rock, alternative, alternative_rock, 90s, grunge  1991       218920
# 3      rock, alternative, indie, alternative_rock, in...  2004       237026
# 4      rock, alternative, indie, alternative_rock, in...  2008       238640
# ...                                                  ...   ...          ...
# ...

# %%
# col to transform
frequency_encode_cols = ['year']
othe_cols = ['artist','time_signature','key']
tfidf_cols = 'tags'
StandardScaler_cols = ['duration_ms','loudness','tempo']
minMaxScaler_cols = ['danceability','energy','speechiness','acousticness','valence','instrumentalness','liveness']

# %%
len(frequency_encode_cols + othe_cols + [tfidf_cols] + StandardScaler_cols + minMaxScaler_cols )
# Out:
# 15

# %%
transformer = ColumnTransformer([
    ('frequency_encode',CountEncoder(normalize=True,return_df=True),frequency_encode_cols),
    ('one_hot_encode',OneHotEncoder(handle_unknown='ignore'),othe_cols),
    ('tfidf',TfidfVectorizer(max_features=85),tfidf_cols),
    ('standard_scale',StandardScaler(),StandardScaler_cols),
    ('min_max_scale',MinMaxScaler(),minMaxScaler_cols)
],remainder='passthrough',n_jobs=-1,force_int_remainder_cols=False)

# %%
transformer.fit(df_colab_filtering)
# Out:
# ColumnTransformer(force_int_remainder_cols=False, n_jobs=-1,
#                   remainder='passthrough',
#                   transformers=[('frequency_encode',
#                                  CountEncoder(combine_min_nan_groups=True,
#                                               normalize=True),
#                                  ['year']),
#                                 ('one_hot_encode',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['artist', 'time_signature', 'key']),
#                                 ('tfidf', TfidfVectorizer(max_features=85),
#                                  'tags'),
#                                 ('standard_scale', StandardScaler(),
#                                  ['duration_ms', 'loudness', 'tempo']),
#                                 ('min_max_scale', MinMaxScaler(),
#                                  ['danceability', 'energy', 'speechiness',
# ...

# %%
transformed_data = transformer.transform(df_colab_filtering)
print(transformed_data.shape)
# Out:
# (50674, 8431)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
#
songs_data.loc[songs_data['artist'] == 'Shakira']
# Out:
#                  track_id                            name   artist  \
# 1025   TRLWDVU128F932B093              Whenever, Wherever  Shakira
# 2068   TRILOWN128F426080F         Underneath Your Clothes  Shakira
# 2205   TRXLMFJ12903CC06F7                        She Wolf  Shakira
# 2469   TRSQAWU128F92EA20F                      La Tortura  Shakira
# 3373   TRINUNP12903CD84D9                    Did It Again  Shakira
# 4318   TROLUWR128F92E5858                  Te Dejo Madrid  Shakira
# 4599   TRLNLES128F932DA8E                            Fool  Shakira
# 4617   TRUIPZL12903CA0BFE                           Rules  Shakira
# 6046   TRAAKDG128F42A0ECB                  Hips Don't Lie  Shakira
# 6818   TRBAHID128F4278EAF               Objection (Tango)  Shakira
# 7007   TRHEBDB128F92E9FC0                    Don't Bother  Shakira
# 11904  TRADBSW128F933A7A8                            Loba  Shakira
# 12305  TRYFVKK128F4240FE8                        Why Wait  Shakira
# ...

# %%
song_name_to_find = 'Whenever, Wherever'
songs_input_original = songs_data[songs_data['name'] == song_name_to_find]

if songs_input_original.empty:
    print(f"Song '{song_name_to_find}' not found in the dataset.")
else:
    # Select only the columns that are present in df_colab_filtering
    cols_for_transform = df_colab_filtering.columns
    songs_input_filtered = songs_input_original[cols_for_transform]
    input_vector = transformer.transform(songs_input_filtered)
    print("Input vector created successfully.")
    print(input_vector.shape)
# Out:
# Input vector created successfully.
# (1, 8431)

# %%
input_vector = transformer.transform(songs_input_filtered)

input_vector
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 20 stored elements and shape (1, 8431)>

# %%
similarity_scores = cosine_similarity(input_vector,transformed_data)

# %%
similarity_scores.shape
# Out:
# (1, 50674)

# %%
top_10_songs_index = np.argsort(similarity_scores[0])[-10:]

# %%
top_10_songs_index
# Out:
# array([38383,  6526,  6121,  7172,  6133, 17241,  6129,  6046, 12305,
#         1025])

# %%
top_10_songs_index = songs_data.iloc[top_10_songs_index]

# %%
top_10_songs_index
# Out:
#                  track_id                    name           artist  \
# 38383  TRWUWRZ128F42ADA4A        Dreams for Plans          Shakira
# 6526   TRXHWIA128E078A9BB            Cruel Summer       Bananarama
# 6121   TRGZIMZ128F930A016          La Isla Bonita          Madonna
# 7172   TRLQBEN128F92E7415             Wild Things     Alessia Cara
# 6133   TRDXCSH128F92ED4A1            Bootylicious  Destiny's Child
# 17241  TRMBDIR128F4279C1F           Perfect Lover   Britney Spears
# 6129   TRBAUVN128F932FEF8  Oops!...I Did It Again   Britney Spears
# 6046   TRAAKDG128F42A0ECB          Hips Don't Lie          Shakira
# 12305  TRYFVKK128F4240FE8                Why Wait          Shakira
# 1025   TRLWDVU128F932B093      Whenever, Wherever          Shakira
#
#                                      spotify_preview_url  \
# 38383  https://p.scdn.co/mp3-preview/6e2c021846087a88...
# 6526   https://p.scdn.co/mp3-preview/47d13ef240a58bef...
# ...

# %%
songs_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-247876328.py in <cell line: 0>()
# ----> 1 top_10_songs_names = top_10_songs_index.loc[top_10_songs_index]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1416             if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#    1417                 if hasattr(key, "ndim") and key.ndim > 1:
# ...

# %%
def recommend(song_name,songs_data,transformed_data,k=10):
  song_row = songs_data.loc[songs_data['name']==song_name,:]
  if song_row.empty:
    print(f"Song '{song_name}' not found in the dataset.")
  else:
    song_index = song_row.index[0]
    print(song_index)
    input_vector = transformed_data[song_index].reshape(1,-1)
    similarity_scores = cosine_similarity(input_vector,transformed_data)
    print(similarity_scores.shape)

    top_k_songs_index = np.argsort(similarity_scores[0])[-k:][::-1]
    print(top_k_songs_index)

    top_k_songs = songs_data.iloc[top_k_songs_index]
    top_k_list =  top_k_songs[['name','artist','spotify_preview_url']].reset_index(drop=True)

    return top_k_list

# %%
recommend('Whenever, Wherever',songs_data,transformed_data=transformed_data,k=10)
# Out:
# 1025
# (1, 50674)
# [ 1025 12305  6046  6129 17241  6133  7172  6121  6526 38383]
#                      name           artist  \
# 0      Whenever, Wherever          Shakira
# 1                Why Wait          Shakira
# 2          Hips Don't Lie          Shakira
# 3  Oops!...I Did It Again   Britney Spears
# 4           Perfect Lover   Britney Spears
# 5            Bootylicious  Destiny's Child
# 6             Wild Things     Alessia Cara
# 7          La Isla Bonita          Madonna
# 8            Cruel Summer       Bananarama
# 9        Dreams for Plans          Shakira
#
#                                  spotify_preview_url
# 0  https://p.scdn.co/mp3-preview/09ddeb4ae33ee6e8...
# 1  https://p.scdn.co/mp3-preview/d78c90c5cb5626be...
# 2  https://p.scdn.co/mp3-preview/3859547944f57cfb...
# 3  https://p.scdn.co/mp3-preview/7fb86827422540ad...
# 4  https://p.scdn.co/mp3-preview/52671e54d36f077e...
# 5  https://p.scdn.co/mp3-preview/7e327ccb1e4c52b2...
# ...
